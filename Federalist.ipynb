# %%
library(stylo)
stylo.results = stylo(
  gui = FALSE,
  features = "wordlist_72.txt",
  write.jpg.file = TRUE,
  custom.graph.filename = "Federalist_CA_72_MFWs_"
)
# summary(stylo.results)
print(stylo.results$features.actually.used)
#
# Out:
# ### stylo version: 0.7.1 ###
#
# If you plan to cite this software (please do!), use the following reference:
#     Eder, M., Rybicki, J. and Kestemont, M. (2016). Stylometry with R:
#     a package for computational text analysis. R Journal 8(1): 107-121.
#     <https://journal.r-project.org/archive/2016/RJ-2016-007/index.html>
#
# To get full BibTeX entry, type: citation("stylo")
#
# using current directory...
#
#
# reading a custom set of features from a file...
#
# Performing no sampling (using entire text as sample)
#
#
# loading Ham_01.txt	...
#
# loading Ham_06.txt	...
#
# loading Ham_07.txt	...
#
# loading Ham_08.txt	...
#
# loading Ham_09.txt	...
#
# loading Ham_11.txt	...
#
# loading Ham_12.txt	...
#
# loading Ham_13.txt	...
#
# loading Ham_15.txt	...
#
# loading Ham_16.txt	...
#
# loading Ham_17.txt	...
#
# loading Ham_21.txt	...
#
# loading Ham_22.txt	...
#
# loading Ham_23.txt	...
#
# loading Ham_24.txt	...
#
# loading Ham_25.txt	...
#
# loading Ham_26.txt	...
#
# loading Ham_27.txt	...
#
# loading Ham_28.txt	...
#
# loading Ham_29.txt	...
#
# loading Ham_30.txt	...
#
# loading Ham_31.txt	...
#
# loading Ham_32.txt	...
#
# loading Ham_33.txt	...
#
# loading Ham_34.txt	...
#
# loading Ham_35.txt	...
#
# loading Ham_36.txt	...
#
# loading Ham_59.txt	...
#
# loading Ham_60.txt	...
#
# loading Ham_61.txt	...
#
# loading Ham_65.txt	...
#
# loading Ham_66.txt	...
#
# loading Ham_67.txt	...
#
# loading Ham_68.txt	...
#
# loading Ham_69.txt	...
#
# loading Ham_70a.txt	...
#
# loading Ham_70b.txt	...
#
# loading Ham_71.txt	...
#
# loading Ham_72.txt	...
#
# loading Ham_73.txt	...
#
# loading Ham_74.txt	...
#
# loading Ham_75.txt	...
#
# loading Ham_76.txt	...
#
# loading Ham_77.txt	...
#
# loading Ham_78.txt	...
#
# loading Ham_79.txt	...
#
# loading Ham_80.txt	...
#
# loading Ham_81.txt	...
#
# loading Ham_82.txt	...
#
# loading Ham_83.txt	...
#
# loading Ham_84.txt	...
#
# loading Ham_85.txt	...
#
# loading Jay_02.txt	...
#
# loading Jay_03.txt	...
#
# loading Jay_04.txt	...
#
# loading Jay_05.txt	...
#
# loading Jay_64.txt	...
#
# loading Joint_18.txt	...
#
# loading Joint_19.txt	...
#
# loading Joint_20.txt	...
#
# loading Mad_10.txt	...
#
# loading Mad_14.txt	...
#
# loading Mad_37.txt	...
#
# loading Mad_38.txt	...
#
# loading Mad_39.txt	...
#
# loading Mad_40.txt	...
#
# loading Mad_41.txt	...
#
# loading Mad_42.txt	...
#
# loading Mad_43.txt	...
#
# loading Mad_44.txt	...
#
# loading Mad_45.txt	...
#
# loading Mad_46.txt	...
#
# loading Mad_47.txt	...
#
# loading Mad_48.txt	...
#
# loading Unk_49.txt	...
#
# loading Unk_50.txt	...
#
# loading Unk_51.txt	...
#
# loading Unk_52.txt	...
#
# loading Unk_53.txt	...
#
# loading Unk_54.txt	...
#
# loading Unk_55.txt	...
#
# loading Unk_56.txt	...
#
# loading Unk_57.txt	...
#
# loading Unk_58.txt	...
#
# loading Unk_62.txt	...
#
# loading Unk_63.txt	...
#
# slicing input text into tokens...
#
#
#
# turning words into features, e.g. char n-grams (if applicable)...
#
#
#
# Total nr. of samples in the corpus: 86
#
#
#
# using an existing wordlist (vector of features)...
#
#
#
# processing  86  text samples
#
# .
# .
# .
# .
# .
# .
# .
# .
#
#
# combining frequencies into a table...
#
#
#
#
# culling @ 0	available features (words) 72
#
# Calculating z-scores...
#
#
# Calculating classic Delta distances...
#
# MFW used:
#
# 72
#
# Processing metadata...
#
#
#
# Assigning plot colors according to file names...
# ------------------------------------------------
# features (e.g. frequent words) actually analyzed
# ------------------------------------------------
#
#   [1]  a       all     also    an      and     any     are     as      at
#  [10]  be      been    but     by      can     do      down    even    every
#  [19]  for     from    had     has     have    her     his     if      in
#  [28]  into    is      it      its     may     more    must    my      no
#  [37]  not     now     of      on      one     only    or      our     shall
#  [46]  should  so      some    such    than    that    the     their   then
#  [55]  there   thing   this    to      up      upon    was     were    what
#  [64]  when    which   who     will    with    would   you     while   whilst
#
# (total number of elements:  72)
# Plot with title “Federalist
#  Cluster Analysis”
